# %%
#Create an integer and a string
year=2014
team='seahawks'

# %%
#print year and team
print year
print team
# Out:
# 2014
# seahawks

# %%
#concatanate string and year
year_string = str(year)
year_team = year_string + team 
print year_team
# Out:
# 2014seahawks

# %%
#Exercise 1: Increase year by more years and then combine that variable, year and team into a string
moreyears=2

#add moreyears to year to create new_year
new_year=
print new_year

#change new_year to the correct variable type
new_year_str=
print new_year_str

#create year_team2
year_team2=

print year_team2
# Out:
#   File "<ipython-input-6-0cc679398ae8>", line 5
#     new_year=
#              ^
# SyntaxError: invalid syntax

# %%
years =[2014,2013,2012]
teams = ['seahawks','ravens','giants']

# %%
print years[0]
print str(teams[1]).capitalize()
print years[2]
# Out:
# 2014
# Ravens
# 2012

# %%
#Exercise 2: Another important list function is .append which adds another element to a list
#Create and print a list that adds three elements to the list the three elements of the list 
#are the sums of all combination the numbers in the list years

years[ ]

years.append

print years
# Out:
#   File "<ipython-input-10-9fc10b804670>", line 5
#     years[ ]
#            ^
# SyntaxError: invalid syntax

# %%
superbowl_chmp ={2014:'seahawks',2013:'ravens',2012:'giants'}
qtr_bcks={'seahawks':'Russel Wilson','ravens':'Joe Flacco', 'Giants':'Eli Manning'}

print superbowl_chmp[2014]
print str(superbowl_chmp[2014]).capitalize()
print qtr_bcks['seahawks']
# Out:
# seahawks
# Seahawks
# Russel Wilson

# %%
#Exercise 3: Create a list of the superbowl winning quarterbacks using superbowl_chmp and qtr_backs dictionaries above

print superbowl_qtr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c797d3efc745> in <module>()
#       1 #Exercise 3: Create a list of the superbowl winning quarterbacks using superbowl_chmp and qtr_backs dictionaries above
#       2
# ----> 3 print superbowl_qtr
#
# NameError: name 'superbowl_qtr' is not defined

# %%
count=2012
while (count<2014):
    print count
    count=count+1
print "done"
# Out:
# 2012
# 2013
# done

# %%
yrs_ago=[0,1,2]
years =[2014,2013,2012]
teams = ['seahawks','ravens','giants']
for i in yrs_ago:
    print "In " + str(years[i]) + ", " + teams[i].capitalize() + " won the Super Bowl"
# Out:
# In 2014, Seahawks won the Super Bowl
# In 2013, Ravens won the Super Bowl
# In 2012, Giants won the Super Bowl

# %%
count=2012
while (count<2014):
    print count
    count=count+1
print "done"
# Out:
# 2012  is  less than 2014
# 2013  is  less than 2014
# 2014  is not less than 2014

# %%
#You can also add an else to your while loops
count = 2012
while count < 2014:
   print count, " is  less than 2014"
   count = count + 1
else:
   print count, " is not less than 2014"
# Out:
# 2012  is  less than 2014
# 2013  is  less than 2014
# 2014  is not less than 2014

# %%
if years[0] == 2013:
    print years[0]
elif years[1] == 2013: 
    print years[1]
else:
    print 'Nothing'
# Out:
# 2013

# %%
#Excercise #4: Redo exercises #2 & #3 using loops

# %%
import pandas as pd
# %matplotlib inline
amzn_stock = pd.read_csv('amazon_stock.csv', sep=',',parse_dates=['Date'],index_col='Date')

# %%
amzn_stock.head(10) #change number for more/less rows
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 2009-09-01  80.74  82.42  79.00  79.16  6245800      79.16
# 2009-09-02  79.04  80.15  77.80  78.14  6512700      78.14
# 2009-09-03  78.39  78.96  77.51  78.46  4140200      78.46
# 2009-09-04  78.27  79.78  77.63  78.87  4671500      78.87
# 2009-09-08  79.86  81.04  78.87  80.90  7037600      80.90
# 2009-09-09  80.60  82.63  80.50  82.24  6776200      82.24
# 2009-09-10  82.33  84.07  82.30  83.85  7023100      83.85
# 2009-09-11  84.44  84.90  83.76  84.54  6006900      84.54
# 2009-09-14  83.81  84.57  83.46  83.86  3572000      83.86
# 2009-09-15  84.17  84.41  82.79  83.55  4446800      83.55

# %%
amzn_stock.describe()
# Out:
#               Open         High          Low        Close           Volume  \
# count  1271.000000  1271.000000  1271.000000  1271.000000      1271.000000
# mean    224.673438   227.345917   221.804823   224.749795   5189088.276947
# std      78.840836    79.371651    78.009177    78.695560   3831781.664454
# min      78.270000    78.960000    77.510000    78.140000    984400.000000
# 25%     169.505000   171.820000   167.165000   169.395000   2948650.000000
# 50%     215.630000   218.230000   212.820000   216.230000   4295100.000000
# 75%     275.880000   279.215000   273.470000   275.915000   6124350.000000
# max     408.000000   408.060000   402.000000   407.050000  58305800.000000
#
#          Adj Close
# count  1271.000000
# mean    224.749795
# std      78.695560
# min      78.140000
# 25%     169.395000
# 50%     216.230000
# 75%     275.915000
# max     407.050000

# %%
#Exercise #1: Print only 3 rows of the summary statistics as well as the summary statistics for the first 5 rows

# %%
amzn_stock.plot()

# %%
amzn_stock.plot(y=['Close','Open'])

# %%
import numpy as np
gp_month = amzn_stock.groupby(pd.TimeGrouper(freq='M')).aggregate(np.mean)

# %%
gp_month.head(10)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2009-09-30   86.272381   87.610476   85.354286   86.742857   6101038
# 2009-10-31  100.950000  102.760000   99.475909  101.243182  12209836
# 2009-11-30  127.753000  129.495000  126.602500  128.587500   8015255
# 2009-12-31  135.670000  137.146364  133.339545  134.895455   9430504
# 2010-01-31  128.361579  129.781053  125.657368  127.423158  12150578
# 2010-02-28  118.192632  119.553158  116.074737  118.021053  11060305
# 2010-03-31  130.296957  132.098261  128.931739  130.897391   6871417
# 2010-04-30  140.897143  143.181905  138.889524  141.070000   8239290
# 2010-05-31  127.790500  130.340500  124.952000  127.606000   7045495
# 2010-06-30  122.325000  124.140000  119.808636  121.667273   6062659
#
#              Adj Close
# Date
# 2009-09-30   86.742857
# 2009-10-31  101.243182
# 2009-11-30  128.587500
# 2009-12-31  134.895455
# 2010-01-31  127.423158
# 2010-02-28  118.021053
# 2010-03-31  130.897391
# 2010-04-30  141.070000
# 2010-05-31  127.606000
# 2010-06-30  121.667273

# %%
gp_month.plot(y=['High','Low'])

# %%
amzn_grouped= amzn_stock.groupby('Open')

# %%
amzn_grouped.aggregate(np.sum)
# Out:
#           High     Low   Close    Volume  Adj Close
# Open
# 78.27    79.78   77.63   78.87   4671500      78.87
# 78.39    78.96   77.51   78.46   4140200      78.46
# 79.04    80.15   77.80   78.14   6512700      78.14
